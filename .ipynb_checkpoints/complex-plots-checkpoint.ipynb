# %%
size = 10
p = complex_plot(lambda z: gamma(z), (-Integer(size), Integer(size)), (-Integer(size), Integer(size)), cmap='jet')                                   
p.show()
p.save("images/gamma2d.png")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
size = 20
p = complex_plot(lambda z: zeta(z), (-Integer(size), Integer(size)), (-Integer(size), Integer(size)), cmap='jet')                                   
p.show()
p.save("images/zeta2d.png")
# Out:
# Graphics object consisting of 1 graphics primitive
